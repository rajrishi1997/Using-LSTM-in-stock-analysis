# %% [markdown]
# # STOCK MARKET ANALYSIS AND PREDICTION USING LSTM

# %% [markdown]
# name-Rajrishi Sarkar
# roll-203110061
# ee769 project

# %% [markdown]
# **Dataset consists of following files:**
#
# **prices.csv:** raw, as-is daily prices. Most of data spans from 2010 to the end 2016, for companies new on stock market date range is shorter. There have been approx. 140   stock splits in that time, this set doesn't account for that.
# prices-split-adjusted.csv: same as prices, but there have been added adjustments for splits.
#
# **securities.csv:** general description of each company with division on sectors
#
# **fundamentals.csv:** metrics extracted from annual SEC 10K fillings (2012-2016), should be enough to derive most of popular fundamental indicators.

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Importing the basic libraries

# %%
#basic libs
import pandas as pd
import numpy as np

#visualizing libs
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import seaborn as sns
from jupyterthemes import jtplot
jtplot.style(theme="monokai",context="notebook",ticks=True,grid=True)

#deep learning libs
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Dropout

#stats libs
from scipy import stats

#preprocessing libs
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#warnings 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Importing files

# %%
df=pd.read_csv("prices.csv")

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Checking the dataset

# %%
df.head()
# Out:
#                   date symbol        open       close         low        high  \
# 0  2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
df.shape
# Out:
# (851264, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    851264 non-null  object
#  1   symbol  851264 non-null  object
#  2   open    851264 non-null  float64
#  3   close   851264 non-null  float64
#  4   low     851264 non-null  float64
#  5   high    851264 non-null  float64
#  6   volume  851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB

# %%
#checking for missing values
df.isna().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %% [markdown]
# there are no missing values in the dataset

# %%
# data satatistics
df.describe().T
# Out:
#            count          mean           std   min           25%  \
# open    851264.0  7.083699e+01  8.369588e+01  0.85  3.384000e+01
# close   851264.0  7.085711e+01  8.368969e+01  0.86  3.385000e+01
# low     851264.0  7.011841e+01  8.287729e+01  0.83  3.348000e+01
# high    851264.0  7.154348e+01  8.446550e+01  0.88  3.419000e+01
# volume  851264.0  5.415113e+06  1.249468e+07  0.00  1.221500e+06
#
#                  50%           75%           max
# open    5.277000e+01  7.988000e+01  1.584440e+03
# close   5.280000e+01  7.989000e+01  1.578130e+03
# low     5.223000e+01  7.911000e+01  1.549940e+03
# high    5.331000e+01  8.061000e+01  1.600930e+03
# volume  2.476250e+06  5.222500e+06  8.596434e+08

# %%
# lets check the number of companies in the dataset
len(df["symbol"].unique())
# Out:
# 501

# %% [markdown]
# 501 companies are listed in the stock dataset

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### Sampling the dataset for the company  "APPLE"

# %% [markdown]
# At the moment we are precisely iteresteed in the stock prices variation of "apple".So we will be sampling all the apple datas from the given dataset and proceed further

# %%
#AAPL is the symbol for apple in NYSE so we will be separating our dataset for apple precisely on the basis of this 
df1=df[df["symbol"]=="AAPL"]
df1.head()
# Out:
#             date symbol        open       close         low        high  \
# 254   2010-01-04   AAPL  213.429998  214.009998  212.380001  214.499996
# 721   2010-01-05   AAPL  214.599998  214.379993  213.249994  215.589994
# 1189  2010-01-06   AAPL  214.379993  210.969995  210.750004  215.230000
# 1657  2010-01-07   AAPL  211.750000  210.580000  209.050005  212.000006
# 2125  2010-01-08   AAPL  210.299994  211.980005  209.060005  212.000006
#
#            volume
# 254   123432400.0
# 721   150476200.0
# 1189  138040000.0
# 1657  119282800.0
# 2125  111902700.0

# %%
df1.describe().T
# Out:
#          count          mean           std           min           25%  \
# open    1762.0  3.130763e+02  1.852995e+02  9.000000e+01  1.152225e+02
# close   1762.0  3.129271e+02  1.851471e+02  9.028000e+01  1.151900e+02
# low     1762.0  3.098282e+02  1.833839e+02  8.947000e+01  1.140025e+02
# high    1762.0  3.159113e+02  1.868982e+02  9.070000e+01  1.163625e+02
# volume  1762.0  9.422578e+07  6.020519e+07  1.147590e+07  4.917478e+07
#
#                  50%           75%           max
# open    3.182300e+02  4.708800e+02  7.024100e+02
# close   3.182400e+02  4.725925e+02  7.021000e+02
# low     3.165450e+02  4.679725e+02  6.995700e+02
# high    3.206000e+02  4.781100e+02  7.050700e+02
# volume  8.050385e+07  1.210816e+08  4.702495e+08

# %%
df1.shape
# Out:
# (1762, 7)

# %%
#converting date to date time
df1["date"]=pd.to_datetime(df1["date"])

# %% [markdown]
# _________________________________________________________________________________________________

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# **Visualising the stock opening and closing prices over the period of 6 years**

# %%
fig,ax=plt.subplots(1,2,figsize=(20,6))
sns.lineplot(data=df1,x="date",y="open",ax=ax[0],color="y").set_title("Opening prices from 2010-17")
sns.lineplot(data=df1,x="date",y="close",ax=ax[1],color="r").set_title("Closing prices from 2010-17")
# Out:
# Text(0.5, 1.0, 'Closing prices from 2010-17')

# %% [markdown]
# **Visualizing the stock volume**

# %% [markdown]
# Volume is counted as the total number of shares that are actually traded (bought and sold) during the trading day or specified set period of time. It is a measure of the total turnover of shares. Each ticket represents a trade and counted towards the total trading volume. While the same shares may be traded back and forth multiple times, the volume is counted on each transaction.

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=df1,x="date",y="volume",color="magenta").set_title("Variation in stock volume of apple from 2010-17")
# Out:
# Text(0.5, 1.0, 'Variation in stock volume of apple from 2010-17')

# %% [markdown]
# **Statistical analysis of the numerical features w.r.t the apple stock data**

# %%
# defining a function to analyse the numerical features statistically
def feature_stats(df,feature):
    #creating the subplots
    fig,ax=plt.subplots(1,3,figsize=(15,5))
    #adding the distribution plot
    sns.distplot(x=df[feature],kde=True,ax=ax[0],color="r").set_title("distribution plot of "+feature)
    #adding the probability plot
    stats.probplot(x=df[feature],plot=ax[1])
    #adding boxplot
    sns.boxplot(x=df[feature],ax=ax[2],color="g").set_title("boxplot of "+feature)

# %%
# dropping the non-numerical columns
df2=df1.drop("date",axis=1)
df2=df2.drop("symbol",axis=1)
# a for loop to apply the drfined function over all the features in df2
for i in df2.columns:
    feature_stats(df2,i)
    plt.show()

# %% [markdown]
# **Checking the correlation between the variables**

# %%
#generating pairplots betweeen the features to take a birds eye view
sns.pairplot(df2,corner=True,diag_kind="kde")

# %% [markdown]
# **now we want "close" as closing price to be our target variable so lets check our correlation of the other features with the target variable**

# %%
#correlation with features
df2.corr()["close"]
# Out:
# open      0.999650
# close     1.000000
# low       0.999834
# high      0.999852
# volume    0.408547
# Name: close, dtype: float64

# %% [markdown]
# "open","low" and "high" are the feqatures which are mostly correlated to the targetet variable "close" i.e the closing price of the apple stocks

# %%
#checking correlation among all the variables
sns.heatmap(df2.corr(),annot=True,cmap="copper")
# Out:
# <AxesSubplot:>

# %% [markdown]
# "high","low" and "open" are highly correlated.We need to avoid multicollinearity

# %% [markdown]
# ______________________________________________

# %% [markdown]
# In sequential models we use a different approach to create the dataset to feed into LSTM model

# %% [markdown]
# # Splitting the data

# %%
#splitting the data into input and target variables
x=df2[["open","volume","high","close"]]
y=df2["close"]
#splitting the data into train set and test set
training_set=x.iloc[:1300].values
test_set=x.iloc[1300:].values

# %% [markdown]
# ___________________

# %% [markdown]
# # Normalization

# %%
#scaling the input features with the help of standard scaler
sc=StandardScaler()
training_set_scaled=sc.fit_transform(training_set)
test_set_scaled=sc.fit_transform(test_set)

# %% [markdown]
# __________________

# %% [markdown]
# ### Creating the input for our model

# %% [markdown]
# making a data structure with 60 time steps and one output

# %%
# the model will look into past 100 timesteps predict the next feature and will continue to do so
length=100
#the training set creation
x_train=[]
y_train=[]
for i in range(length,len(training_set)):
    x_train.append(training_set_scaled[i-length:i,0])
    y_train.append(training_set_scaled[i,0])
#converting train set into array
x_train,y_train=np.array(x_train),np.array(y_train)
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))


# The testing set creation
x_test=[]
y_test=[]
for i in range(length,len(test_set)):
    x_test.append(test_set_scaled[i-length:i,0])
    y_test.append(test_set_scaled[i,0])
# converting test set into array
x_test,y_test=np.array(x_test),np.array(y_test)
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

# %%
#checking the shape of the created datastructures
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((1200, 100, 1), (1200,), (362, 100, 1), (362,))

# %% [markdown]
# _______________________________

# %% [markdown]
# # Modelling

# %% [markdown]
# #### Fitting the data into a lstm model

# %% [markdown]
# The LSTM model will learn a function that maps a sequence of past observations as input to an output observation. ... We can divide the sequence into multiple input/output patterns called samples, where three time steps are used as input and one time step is used as output for the one-step prediction that is being learned

# %%
model=Sequential()
#adding the first layer with dropout regularization
model.add(LSTM(units=50,return_sequences=True,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))
#adding second layer to the lstm model with dropout regularization
#model.add(LSTM(units=50,return_sequences=True))
#model.add(Dropout(0.2))
#adding the third layer with dropout regularization
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
#aedding the 4th layer alongwith dropout regularization
model.add(LSTM(units=50))
model.add(Dropout(0.2))
#adding the output layer
model.add(Dense(units=1))
#compiling the recurrent neural network model
model.compile(loss="mean_squared_error",optimizer="adam")
#fitting the model to the training set
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 23s 284ms/step - loss: 0.2275 - val_loss: 0.1997
# Epoch 2/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0850 - val_loss: 0.1727
# Epoch 3/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0724 - val_loss: 0.1313
# Epoch 4/100
# 38/38 [==============================] - 7s 198ms/step - loss: 0.0629 - val_loss: 0.1319
# Epoch 5/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0541 - val_loss: 0.1084
# Epoch 6/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0538 - val_loss: 0.0976
# Epoch 7/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0501 - val_loss: 0.1075
# Epoch 8/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0431 - val_loss: 0.0895
# Epoch 9/100
# 38/38 [==============================] - 7s 198ms/step - loss: 0.0430 - val_loss: 0.0940
# Epoch 10/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0421 - val_loss: 0.0928
# Epoch 11/100
# 38/38 [==============================] - 8s 201ms/step - loss: 0.0385 - val_loss: 0.0925
# Epoch 12/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0426 - val_loss: 0.0827
# Epoch 13/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0370 - val_loss: 0.0933
# Epoch 14/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0359 - val_loss: 0.0870
# Epoch 15/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0328 - val_loss: 0.0907
# Epoch 16/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0317 - val_loss: 0.0807
# Epoch 17/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0323 - val_loss: 0.0886
# Epoch 18/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0283 - val_loss: 0.0809
# Epoch 19/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0305 - val_loss: 0.0866
# Epoch 20/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0273 - val_loss: 0.0831
# Epoch 21/100
# 38/38 [==============================] - 7s 197ms/step - loss: 0.0287 - val_loss: 0.0781
# Epoch 22/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0307 - val_loss: 0.0792
# Epoch 23/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0258 - val_loss: 0.0821
# Epoch 24/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0282 - val_loss: 0.0729
# Epoch 25/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0269 - val_loss: 0.0755
# Epoch 26/100
# 38/38 [==============================] - 7s 198ms/step - loss: 0.0289 - val_loss: 0.0746
# Epoch 27/100
# 38/38 [==============================] - 8s 206ms/step - loss: 0.0265 - val_loss: 0.0727
# Epoch 28/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0277 - val_loss: 0.0727
# Epoch 29/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0219 - val_loss: 0.0825
# Epoch 30/100
# 38/38 [==============================] - 8s 205ms/step - loss: 0.0227 - val_loss: 0.0697
# Epoch 31/100
# 38/38 [==============================] - 8s 206ms/step - loss: 0.0284 - val_loss: 0.0737
# Epoch 32/100
# 38/38 [==============================] - 8s 201ms/step - loss: 0.0254 - val_loss: 0.0682
# Epoch 33/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0254 - val_loss: 0.0677
# Epoch 34/100
# 38/38 [==============================] - 8s 202ms/step - loss: 0.0229 - val_loss: 0.0699
# Epoch 35/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0249 - val_loss: 0.0670
# Epoch 36/100
# 38/38 [==============================] - 7s 197ms/step - loss: 0.0243 - val_loss: 0.0695
# Epoch 37/100
# 38/38 [==============================] - 7s 198ms/step - loss: 0.0219 - val_loss: 0.0645
# Epoch 38/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0220 - val_loss: 0.0665
# Epoch 39/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0242 - val_loss: 0.0688
# Epoch 40/100
# 38/38 [==============================] - 7s 198ms/step - loss: 0.0234 - val_loss: 0.0834
# Epoch 41/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0243 - val_loss: 0.0683
# Epoch 42/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0214 - val_loss: 0.0698
# Epoch 43/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0222 - val_loss: 0.0620
# Epoch 44/100
# 38/38 [==============================] - 7s 198ms/step - loss: 0.0238 - val_loss: 0.0624
# Epoch 45/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0216 - val_loss: 0.0641
# Epoch 46/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0211 - val_loss: 0.0634
# Epoch 47/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0214 - val_loss: 0.0702
# Epoch 48/100
# 38/38 [==============================] - 8s 201ms/step - loss: 0.0216 - val_loss: 0.0643
# Epoch 49/100
# 38/38 [==============================] - 8s 201ms/step - loss: 0.0227 - val_loss: 0.0632
# Epoch 50/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0222 - val_loss: 0.0603
# Epoch 51/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0208 - val_loss: 0.0624
# Epoch 52/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0218 - val_loss: 0.0614
# Epoch 53/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0225 - val_loss: 0.0618
# Epoch 54/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0234 - val_loss: 0.0638
# Epoch 55/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0205 - val_loss: 0.0582
# Epoch 56/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0222 - val_loss: 0.0597
# Epoch 57/100
# 38/38 [==============================] - 8s 205ms/step - loss: 0.0227 - val_loss: 0.0638
# Epoch 58/100
# 38/38 [==============================] - 8s 208ms/step - loss: 0.0221 - val_loss: 0.0647
# Epoch 59/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0216 - val_loss: 0.0612- loss
# Epoch 60/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0247 - val_loss: 0.0622
# Epoch 61/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0206 - val_loss: 0.0580
# Epoch 62/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0199 - val_loss: 0.0640
# Epoch 63/100
# 38/38 [==============================] - 8s 204ms/step - loss: 0.0234 - val_loss: 0.0559 0s - loss: 0.
# Epoch 64/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0218 - val_loss: 0.0616
# Epoch 65/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0213 - val_loss: 0.0551
# Epoch 66/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0220 - val_loss: 0.0571
# Epoch 67/100
# 38/38 [==============================] - 8s 201ms/step - loss: 0.0207 - val_loss: 0.0696
# Epoch 68/100
# 38/38 [==============================] - 8s 213ms/step - loss: 0.0233 - val_loss: 0.0569
# Epoch 69/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0220 - val_loss: 0.0579
# Epoch 70/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0213 - val_loss: 0.0582
# Epoch 71/100
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0199 - val_loss: 0.0556
# Epoch 72/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0199 - val_loss: 0.0579
# Epoch 73/100
# 38/38 [==============================] - 8s 198ms/step - loss: 0.0253 - val_loss: 0.0578
# Epoch 74/100
# 38/38 [==============================] - 8s 216ms/step - loss: 0.0229 - val_loss: 0.0563
# Epoch 75/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0217 - val_loss: 0.0561
# Epoch 76/100
# 38/38 [==============================] - 9s 248ms/step - loss: 0.0198 - val_loss: 0.0558
# Epoch 77/100
# 38/38 [==============================] - 8s 224ms/step - loss: 0.0207 - val_loss: 0.0573
# Epoch 78/100
# 38/38 [==============================] - 9s 243ms/step - loss: 0.0179 - val_loss: 0.0570
# Epoch 79/100
# 38/38 [==============================] - 8s 201ms/step - loss: 0.0210 - val_loss: 0.0592
# Epoch 80/100
# 38/38 [==============================] - 8s 216ms/step - loss: 0.0217 - val_loss: 0.0572
# Epoch 81/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0223 - val_loss: 0.0572
# Epoch 82/100
# 38/38 [==============================] - 8s 200ms/step - loss: 0.0189 - val_loss: 0.0568
# Epoch 83/100
# 38/38 [==============================] - 8s 203ms/step - loss: 0.0202 - val_loss: 0.0586
# Epoch 84/100
# 38/38 [==============================] - 8s 203ms/step - loss: 0.0197 - val_loss: 0.0633
# Epoch 85/100
# 38/38 [==============================] - 8s 205ms/step - loss: 0.0215 - val_loss: 0.0656
# Epoch 86/100
# 38/38 [==============================] - 8s 219ms/step - loss: 0.0199 - val_loss: 0.0585
# Epoch 87/100
# 38/38 [==============================] - 8s 217ms/step - loss: 0.0218 - val_loss: 0.0636oss: 0.02
# Epoch 88/100
# 38/38 [==============================] - 8s 212ms/step - loss: 0.0205 - val_loss: 0.0587
# Epoch 89/100
# 38/38 [==============================] - 8s 221ms/step - loss: 0.0203 - val_loss: 0.0662
# Epoch 90/100
# 38/38 [==============================] - 9s 228ms/step - loss: 0.0205 - val_loss: 0.0602
# Epoch 91/100
# 38/38 [==============================] - 8s 221ms/step - loss: 0.0199 - val_loss: 0.0553
# Epoch 92/100
# 38/38 [==============================] - 9s 247ms/step - loss: 0.0182 - val_loss: 0.0617
# Epoch 93/100
# 38/38 [==============================] - 9s 237ms/step - loss: 0.0205 - val_loss: 0.0548
# Epoch 94/100
# 38/38 [==============================] - 9s 227ms/step - loss: 0.0193 - val_loss: 0.0573
# Epoch 95/100
# 38/38 [==============================] - 9s 229ms/step - loss: 0.0200 - val_loss: 0.0606
# Epoch 96/100
# 38/38 [==============================] - 8s 199ms/step - loss: 0.0200 - val_loss: 0.0542
# Epoch 97/100
# 38/38 [==============================] - 8s 218ms/step - loss: 0.0222 - val_loss: 0.0646
# Epoch 98/100
# 38/38 [==============================] - 9s 230ms/step - loss: 0.0213 - val_loss: 0.0553 2s - l - ETA: 0s - loss: 0.
# Epoch 99/100
# 38/38 [==============================] - 8s 223ms/step - loss: 0.0269 - val_loss: 0.0545
# Epoch 100/100
# 38/38 [==============================] - 9s 240ms/step - loss: 0.0229 - val_loss: 0.0573

# %% [markdown]
# **Plotting the validation loss vs epochs**

# %%
#creating the dataframe contaning the validation loss and  train_inver_transform
loss=pd.DataFrame(model.history.history)
plt.figure(figsize=(15,5))
plt.plot(loss)
plt.title("losses vs epochs")
plt.legend(["train_loss","validation_loss"])

# %% [markdown]
# **predicting the stock prices**

# %%
#creating a dataframe that consists of the test data and predicted data side by side in two columns
pred=model.predict(x_test)
test=pd.DataFrame(columns=["test","pred"])
test["test"]=y_test
test["pred"]=pred.flatten()
#checking the dataframne created
test.head(10)
# Out:
#        test      pred
# 0  1.060551  1.173213
# 1  1.039555  1.146749
# 2  0.963786  1.137934
# 3  0.989346  1.103054
# 4  0.888930  1.086012
# 5  0.516474  1.035221
# 6  0.108417  0.780998
# 7  0.384107  0.295874
# 8  0.257217  0.233349
# 9  0.435228  0.244898

# %% [markdown]
# **Plotting the test values vs the LSTM predicted values**

# %%
from sklearn.metrics import mean_squared_error,r2_score
#the lineplot
plt.figure(figsize=(15,7))
plt.plot(test)
plt.title("Test values vs Predicted values")
plt.legend(["test","pred"])
#calculating the losses
r2=np.round(r2_score(y_test,pred),2)
mse=np.round(mean_squared_error(y_test,pred),2)
#incorporating the losses in the plot
plt.text(x=320,y=-1.0,s="R2 score:{}".format(r2))
plt.text(x=320,y=-1.25,s="MSE:{}".format(mse))
# Out:
# Text(320, -1.25, 'MSE:0.06')

# %% [markdown]
# the model is clearly overfitting and as a consequence the accuracy of the model gets affected,since we can't provide more company data,we take our chances and reduce the number of layers in the lstm model and check if th e model performace increases

# %% [markdown]
# **going for further accuracy enhancements**

# %%
model=Sequential()
#adding the first layer with dropout regularization
model.add(LSTM(units=50,return_sequences=True,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))
#adding the next layer(2nd layer)
model.add(LSTM(units=50))
model.add(Dropout(0.2))
#adding the output layer
model.add(Dense(units=1))
#compiling the recurrent neural network model
model.compile(loss="mean_squared_error",optimizer="adam")
#fitting the model to the training set
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,batch_size=30)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 20s 272ms/step - loss: 0.1878 - val_loss: 0.1584
# Epoch 2/100
# 40/40 [==============================] - 8s 212ms/step - loss: 0.0658 - val_loss: 0.1414
# Epoch 3/100
# 40/40 [==============================] - 10s 240ms/step - loss: 0.0566 - val_loss: 0.1043
# Epoch 4/100
# 40/40 [==============================] - 9s 231ms/step - loss: 0.0499 - val_loss: 0.0978
# Epoch 5/100
# 40/40 [==============================] - 10s 243ms/step - loss: 0.0460 - val_loss: 0.0933
# Epoch 6/100
# 40/40 [==============================] - 9s 223ms/step - loss: 0.0414 - val_loss: 0.0875
# Epoch 7/100
# 40/40 [==============================] - 8s 213ms/step - loss: 0.0397 - val_loss: 0.0828
# Epoch 8/100
# 40/40 [==============================] - 8s 188ms/step - loss: 0.0357 - val_loss: 0.0815
# Epoch 9/100
# 40/40 [==============================] - 8s 196ms/step - loss: 0.0375 - val_loss: 0.0750
# Epoch 10/100
# 40/40 [==============================] - 8s 199ms/step - loss: 0.0345 - val_loss: 0.0853
# Epoch 11/100
# 40/40 [==============================] - 9s 219ms/step - loss: 0.0346 - val_loss: 0.0766
# Epoch 12/100
# 40/40 [==============================] - 6s 147ms/step - loss: 0.0309 - val_loss: 0.0675
# Epoch 13/100
# 40/40 [==============================] - 4s 108ms/step - loss: 0.0356 - val_loss: 0.0840
# Epoch 14/100
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0288 - val_loss: 0.0649
# Epoch 15/100
# 40/40 [==============================] - 4s 108ms/step - loss: 0.0271 - val_loss: 0.0670
# Epoch 16/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0287 - val_loss: 0.0676
# Epoch 17/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0302 - val_loss: 0.0725
# Epoch 18/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0283 - val_loss: 0.0610
# Epoch 19/100
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0270 - val_loss: 0.0644
# Epoch 20/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0278 - val_loss: 0.0598
# Epoch 21/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0246 - val_loss: 0.0598
# Epoch 22/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0229 - val_loss: 0.0588
# Epoch 23/100
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0234 - val_loss: 0.0578
# Epoch 24/100
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0249 - val_loss: 0.0559
# Epoch 25/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0253 - val_loss: 0.0549
# Epoch 26/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0220 - val_loss: 0.0577
# Epoch 27/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0233 - val_loss: 0.0556
# Epoch 28/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0243 - val_loss: 0.0629
# Epoch 29/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0243 - val_loss: 0.0554
# Epoch 30/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0227 - val_loss: 0.0557
# Epoch 31/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0220 - val_loss: 0.0543
# Epoch 32/100
# 40/40 [==============================] - 4s 103ms/step - loss: 0.0225 - val_loss: 0.0566
# Epoch 33/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0194 - val_loss: 0.0522
# Epoch 34/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0200 - val_loss: 0.0544
# Epoch 35/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0234 - val_loss: 0.0533
# Epoch 36/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0221 - val_loss: 0.0553
# Epoch 37/100
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0212 - val_loss: 0.0534:
# Epoch 38/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0232 - val_loss: 0.0534
# Epoch 39/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0224 - val_loss: 0.0523
# Epoch 40/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0230 - val_loss: 0.0510
# Epoch 41/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0213 - val_loss: 0.0527
# Epoch 42/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0206 - val_loss: 0.0512
# Epoch 43/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0199 - val_loss: 0.0518
# Epoch 44/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0221 - val_loss: 0.0633
# Epoch 45/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0220 - val_loss: 0.0490
# Epoch 46/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0219 - val_loss: 0.0508
# Epoch 47/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0192 - val_loss: 0.0516
# Epoch 48/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0204 - val_loss: 0.0502
# Epoch 49/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0200 - val_loss: 0.0502
# Epoch 50/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0208 - val_loss: 0.0501
# Epoch 51/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0213 - val_loss: 0.0511
# Epoch 52/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0205 - val_loss: 0.0511
# Epoch 53/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0228 - val_loss: 0.0550
# Epoch 54/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0199 - val_loss: 0.0493
# Epoch 55/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0191 - val_loss: 0.0497
# Epoch 56/100
# 40/40 [==============================] - 4s 103ms/step - loss: 0.0220 - val_loss: 0.0524
# Epoch 57/100
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0213 - val_loss: 0.0496
# Epoch 58/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0184 - val_loss: 0.0495
# Epoch 59/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0222 - val_loss: 0.0488
# Epoch 60/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0190 - val_loss: 0.0490
# Epoch 61/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0212 - val_loss: 0.0484
# Epoch 62/100
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0203 - val_loss: 0.0478
# Epoch 63/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0204 - val_loss: 0.0510
# Epoch 64/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0187 - val_loss: 0.0528
# Epoch 65/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0195 - val_loss: 0.0476
# Epoch 66/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0188 - val_loss: 0.0478
# Epoch 67/100
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0211 - val_loss: 0.0481
# Epoch 68/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0204 - val_loss: 0.0513
# Epoch 69/100
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0196 - val_loss: 0.0477
# Epoch 70/100
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0207 - val_loss: 0.0482
# Epoch 71/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0192 - val_loss: 0.0470
# Epoch 72/100
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0187 - val_loss: 0.0459
# Epoch 73/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0197 - val_loss: 0.0480
# Epoch 74/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0216 - val_loss: 0.0517
# Epoch 75/100
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0202 - val_loss: 0.0466
# Epoch 76/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0216 - val_loss: 0.0480
# Epoch 77/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0189 - val_loss: 0.0454
# Epoch 78/100
# 40/40 [==============================] - 4s 88ms/step - loss: 0.0216 - val_loss: 0.0471
# Epoch 79/100
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0193 - val_loss: 0.0475
# Epoch 80/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0197 - val_loss: 0.0489
# Epoch 81/100
# 40/40 [==============================] - 4s 92ms/step - loss: 0.0193 - val_loss: 0.0550
# Epoch 82/100
# 40/40 [==============================] - 5s 115ms/step - loss: 0.0217 - val_loss: 0.0466
# Epoch 83/100
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0203 - val_loss: 0.0487
# Epoch 84/100
# 40/40 [==============================] - 4s 102ms/step - loss: 0.0215 - val_loss: 0.0461
# Epoch 85/100
# 40/40 [==============================] - 5s 125ms/step - loss: 0.0213 - val_loss: 0.0492
# Epoch 86/100
# 40/40 [==============================] - 4s 103ms/step - loss: 0.0180 - val_loss: 0.0470
# Epoch 87/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0216 - val_loss: 0.0460
# Epoch 88/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0194 - val_loss: 0.0454
# Epoch 89/100
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0209 - val_loss: 0.0467
# Epoch 90/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0189 - val_loss: 0.0468
# Epoch 91/100
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0223 - val_loss: 0.0477
# Epoch 92/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0202 - val_loss: 0.0514
# Epoch 93/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0207 - val_loss: 0.0463
# Epoch 94/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0214 - val_loss: 0.0471
# Epoch 95/100
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0173 - val_loss: 0.0448
# Epoch 96/100
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0218 - val_loss: 0.0460
# Epoch 97/100
# 40/40 [==============================] - 4s 102ms/step - loss: 0.0168 - val_loss: 0.0470
# Epoch 98/100
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0209 - val_loss: 0.0499s:
# Epoch 99/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0203 - val_loss: 0.0497
# Epoch 100/100
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0193 - val_loss: 0.0458

# %%
#creating a dataframe that consists of the test data and predicted data side by side in two columns
pred=model.predict(x_test)
test=pd.DataFrame(columns=["test","pred"])
test["test"]=y_test
test["pred"]=pred.flatten()
#the lineplot
plt.figure(figsize=(15,7))
plt.plot(test)
plt.title("Test values vs Predicted values")
plt.legend(["test","pred"])
#calculating the losses
r2=np.round(r2_score(y_test,pred),2)
mse=np.round(mean_squared_error(y_test,pred),2)
#incorporating the losses in the plot
plt.text(x=320,y=-1.0,s="R2 score:{}".format(r2))
plt.text(x=320,y=-1.25,s="MSE:{}".format(mse))
# Out:
# Text(320, -1.25, 'MSE:0.05')
